# %% [markdown]
# This Jupiter notebook is used to download, pre-process and save data about all test data in the Czech Republic from
# the webpage of the Czech...... Output from this notebook is CSV file with downloaded data about........ that will be further processed, cleaned and aggregated.

# %% [markdown]
# os package is used only to check whether we are in the correct working directory.
#
# In the def, we will be applying methods from requests (downloading site content), BeautifulSoup (machine reading of downloaded data), tqdm (interactive measurement of the downloading progress) and time (setting pause between requests from the site) packages.
#
# After the data are downloaded we use pandas to pre-process and save them.

# %% [markdown]
# After downloading the packages, I will check the data structure in order to make sure that we can scrape the given information
# here below we used BeutfulSoup library to request the data.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
from tqdm import tqdm
import re
import numpy as np
html_text = requests.get("https://testovani.uzis.cz/").text.strip()
soup = BeautifulSoup(html_text, 'lxml')
print(soup.prettify())

for i in soup.text[:5]:
    print(i)
# Out:
# <!DOCTYPE html>
# <html lang="cs">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    UZIS | Přehled odběrových míst | PCR
#   </title>
#   <link href="/Content/css?v=rou6514WQETDFOSHN9QNsoCvd1wkfvfKli0EotsUA1E1" rel="stylesheet"/>
#   <script src="/bundles/modernizr?v=FbJ688fulsybP2-T20QPXT8LQsQ1mhbdTSDTuHaeXms1">
#   </script>
#   <script src="/Scripts/jquery-3.5.1.min.js">
#   </script>
#   <script src="/Scripts/jquery.unobtrusive-ajax.min.js">
#   </script>
#   <script defer="" src="https://maps.googleapis.com/maps/api/js?key=AIzaSyCEM0ebgbMPrXyn1FdH1tjJPyAqWVEBnJA&amp;callback=initMap">
#   </script>
#   <script type="text/javascript">
#    var appInsights = window.appInsights || function (config) {
#             function r(config) { t[config] = function () { var i = arguments; t.queue.push(function () { t[config].apply(t, i) }) } }
#             var t = { config: config }, u = document, e = window, o = 'script', s = u.createElement(o), i, f; for (s.src = config.url || '//az416426.vo.msecnd.net/scripts/a/ai.0.js', u.getElementsByTagName(o)[0].parentNode.appendChild(s), t.cookie = u.cookie, t.queue = [], i = ['Event', 'Exception', 'Metric', 'PageView', 'Trace', 'Ajax']; i.length;)r('track' + i.pop()); return r('setAuthenticatedUserContext'), r('clearAuthenticatedUserContext'), config.disableExceptionTracking || (i = 'onerror', r('_' + i), f = e[i], e[i] = function (config, r, u, e, o) { var s = f && f(config, r, u, e, o); return s !== !0 && t['_' + i](config, r, u, e, o), s }), t
#         }({
#             instrumentationKey: 'ea033629-bfb3-4630-8939-bbef898751da'
#         });
#
#         window.appInsights = appInsights;
#         appInsights.trackPageView();
#   </script>
#   <!-- Global site tag (gtag.js) - Google Analytics -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-QL76YQ0263">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#         function gtag() { dataLayer.push(arguments); }
#         gtag('js', new Date());
#
#         gtag('config', 'G-QL76YQ0263');
#   </script>
#  </head>
#  <body class="sub-page">
#   <div class="main__container">
#    <div id="nahoru">
#    </div>
#    <p class="nav-skip">
#     <a accesskey="1" href="/Accessibility/Shortcuts">
#      Klávesové zkratky na tomto webu
#     </a>
#     <a accesskey="0" href="#content">
#      Přejít k obsahu
#     </a>
#    </p>
#    <div class="header">
#     <div class="section section--xl">
#      <div class="header__main">
#       <div class="header__content">
#        <div class="sitelogo">
#         <a accesskey="2" href="https://koronavirus.mzcr.cz">
#          <img alt="Ministerstvo zdravotnictví České republiky" src="/Content/Images/logo-cs.svg" width="316"/>
#         </a>
#        </div>
#        <p class="siteslogan">
#         Odběrová místa COVID-19 (PCR testy)
#        </p>
#        <a href="/Antigen">
#         <span class="header__pcrag__link">
#          Přepnout na místa s Antigenními testy
#         </span>
#        </a>
#       </div>
#       <div class="header__aside__main">
#        <div class="search">
#         <form action="/" method="post">
#          <div class="search__form">
#           <input accesskey="4" class="search__input" id="searchText" label="Hledat" name="searchText" placeholder="Hledat" type="text" value=""/>
#           <button class="search__btn" type="submit">
#            Vyhledat
#           </button>
#          </div>
#         </form>
#        </div>
#        <div class="dropdown">
#         <button aria-expanded="false" aria-haspopup="true" class="dropdown__toggle" data-toggle="dropdown" id="dropdownMenuButton" type="button">
#          Menu
#         </button>
#         <div aria-labelledby="dropdownMenuButton" class="dropdown-menu">
#          <span class="dropdown__menu__header">
#           PCR testy
#          </span>
#          <a class="dropdown-item active" href="/">
#           Odběrová místa
#          </a>
#          <a class="dropdown-item not-active" href="/Report?backURL=%2F">
#           Přehled kapacity
#          </a>
#          <div style="height:20px;">
#          </div>
#          <span class="dropdown__menu__header">
#           Antigenní testy
#          </span>
#          <a class="dropdown-item not-active" href="/Antigen">
#           Odběrová místa
#          </a>
#          <a class="dropdown-item not-active" href="/Antigen/Report?backURL=%2F">
#           Přehled kapacity
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <!-- /header__main -->
#     </div>
#    </div>
#    <div class="main">
#     <div accesskey="0" class="section" id="content" label="Content">
#      <div class="intro">
#       <div class="info__banner">
#        <div class="i__icon">
#        </div>
#        <span>
#         <strong>
#          RT-PCR
#         </strong>
#         testy jsou pro osoby se zdravotním pojištěním v ČR v současnosti poskytovány zdarma dvakrát do měsíce všem účastníkům veřejného pojištění bez výjimek.
#         <br/>
#         <br/>
#         <strong>
#          Antigenní
#         </strong>
#         testy jsou pro osoby se zdravotním pojištěním v ČR v současnosti poskytovány zdarma jednou za sedm dnů všem účastníkům veřejného pojištění bez výjimek.
#         <br/>
#         <br/>
#         <strong>
#          Tento portál průběžně načítá data z 67 různých IT systémů a 234 odběrových míst. Data z přímo napojených odběrových míst  jsou aktualizována každých 10 minut, data z ostatních systémů jsou aktualizována jednou za hodinu.
#         </strong>
#         <br/>
#         <br/>
#         Čas poslední aktualizace dat je: 30.06.2021 21:49.
#         <br/>
#         Doporučujeme kontrolu reálného stavu na odkazu v detailu daného odběrového místa. Některá odběrová místa ještě nejsou napojena (vyznačeno šedivou barvou).
#         <br/>
#         <br/>
#         <a class="data__txt" href="https://odbery.kr-vysocina.cz/odber-info/ezadanka" style="width: 300px;/* height: 100px; */padding: 7px;/* font-weight: 100; */" target="_blank">
#          Rezervační systém Kraje Vysočina
#         </a>
#         <p style="color: gray;font-size: 14px;">
#          (rezervace termínu odběrů antigenních testů, PCR testů samoplátců i PCR osob s eŽádankou v odběrových místech v Kraji Vysočina)
#         </p>
#        </span>
#       </div>
#       <div class="intro__aside">
#        <a class="btn btn--primary" href="/Content/Images/letak-pravidla-pri-navsteve-OM-v1.jpg">
#         Pravidla pro návštěvu odběrového místa
#        </a>
#       </div>
#      </div>
#      <h1 class="midi">
#       Přehled odběrových míst
#      </h1>
#      <div class="gmap">
#       <div class="gmap__map">
#        <iframe allow="geolocation,fullscreen" frameborder="0" height="600" scrolling="no" src="https://covid.uzis.cz/odberova-mista?extent=-86.179,39.923,-85.932,40.075" style="width:100%" title="Mapa odběrových míst">
#        </iframe>
#       </div>
#      </div>
#      <div id="resultsListView">
#       <div class="map-search">
#        <div class="map-search__left">
#         <div class="map-search__form">
#          <form action="/Home/Search" data-ajax="true" data-ajax-complete="scrollToList" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" id="form0" method="post">
#           <input class="map-search__input" id="searchText" name="searchText" placeholder="Hledat" type="text" value=""/>
#           <button class="map-search__btn" type="submit">
#            Vyhledat
#           </button>
#          </form>
#         </div>
#        </div>
#        <div class="map-search__right">
#         <button class="map-search__position" onclick="getLocation('Home')" type="button">
#          Hledat podle mé polohy
#         </button>
#        </div>
#       </div>
#       <div class="data">
#        <div class="data__header" data-target="#data__list" data-toggle="collapse">
#         <h2>
#          <span class="hide-tablet">
#           Vybrat kraj
#          </span>
#          <span class="hide-phone" data-target="#data__list" data-toggle="collapse">
#           Kraj
#          </span>
#         </h2>
#         <span class="icon icon--arrow-down">
#         </span>
#        </div>
#        <div class="data__list collapse" id="data__list">
#         <a class="data__remove" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/ResetFilterRegion">
#          Zrušit výběr
#         </a>
#         <ul class="reset">
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=4c345330-7351-447b-a833-d7250315c5ab">
#             Hlavní město Praha
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=e3440fe6-af92-49d8-86bb-7baf5f07eab9">
#             Jihočeský
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=37872f26-05bd-4ee9-b6f0-352d0e7b842f">
#             Jihomoravský
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=95c937f8-2396-4fb4-bff4-b7ff44382550">
#             Karlovarský
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=da7ec857-c3d3-40b6-a974-f0529c1df452">
#             Královéhradecký
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=82319e48-48b7-47b0-9e37-ea17f286fadd">
#             Liberecký
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=366eef7e-c8d5-4ca3-9ef5-5d4e5d79b366">
#             Moravskoslezský
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=9e28f0cc-41ed-493c-803b-935464c2da8a">
#             Olomoucký
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=51642168-7ee7-4377-817c-5767f1f282f8">
#             Pardubický
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=9aad0e1c-0e4d-4351-b371-0e43bf3d538d">
#             Plzeňský
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=2b3e2460-04a9-45af-b98b-3d7d575784b6">
#             Středočeský
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=6b3b6ce3-949b-40f4-88d2-0d49486f97a0">
#             Ústecký
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=c403cdd6-683b-4ed6-8236-0be5f1d65e0a">
#             Vysočina
#            </a>
#           </label>
#          </li>
#          <li>
#           <label class="data__btn">
#            <a class="data__txt" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#resultsListView" href="/Home/FilterRegion?region=bd9dd94b-7b3b-4b46-9c01-3b5abf0330ef">
#             Zlínský
#            </a>
#           </label>
#          </li>
#         </ul>
#        </div>
#       </div>
#       <div class="list">
#        <div style="text-align: end;">
#         Kapacity jsou vypočítány z rezervačních systémů AOC, které jsou připojeny do CRS.
#        </div>
#        <div class="overview__header">
#         <div class="overview__headline">
#          <h2>
#           Všechna odběrová místa
#           <span class="thin">
#            (
#           </span>
#           369
#           <span class="thin">
#            )
#           </span>
#          </h2>
#         </div>
#         <div class="overview__meta">
#          <div class="overview__legend">
#           <ul class="reset">
#            <li>
#             <img alt="Malá vytíženost" src="/Content/Images/mala.svg" width="20"/>
#             <span>
#              Malá
#             </span>
#            </li>
#            <li>
#             <img alt="Střední vytíženost" src="/Content/Images/stredni.svg" width="20"/>
#             <span>
#              Střední
#             </span>
#            </li>
#            <li>
#             <img alt="Velká vytíženost" src="/Content/Images/velka.svg" width="20"/>
#             <span>
#              Velká
#             </span>
#            </li>
#            <li>
#             <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" width="20"/>
#             <span>
#              Zavřeno
#             </span>
#            </li>
#            <li>
#             <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" width="20"/>
#             <span>
#              OM se připojuje
#             </span>
#            </li>
#           </ul>
#          </div>
#         </div>
#        </div>
#        <div class="list__headline">
#         <h3>
#          Hlavní město Praha
#          <span class="thin">
#           (Počet OM:
#          </span>
#          104
#          <span class="thin">
#           - V následujících
#          </span>
#          3
#          <span class="thin">
#           dnech volná/celková kapacita:
#          </span>
#          14170 / 25171
#          <span class="thin">
#           )
#          </span>
#         </h3>
#        </div>
#        <div class="list__results" id="HlavníměstoPraha">
#         <div class="list__results">
#          <div class="occu__header__holder">
#           <div class="occu__header__spacer">
#            <span>
#            </span>
#           </div>
#           <div class="occu__header">
#            <span>
#             Vytíženost
#            </span>
#           </div>
#          </div>
#          <div class="list__meta">
#           <div class="list__col">
#            <a class="list__sort is-dsc" data-ajax="true" data-ajax-method="POST" data-ajax-mode="replace" data-ajax-update="#HlavníměstoPraha" href="/Home/SortBy?asc=True&amp;regionID=4c345330-7351-447b-a833-d7250315c5ab&amp;isSearchActive=False">
#             Název
#            </a>
#           </div>
#           <div class="list__col">
#            <span>
#             Příjem
#            </span>
#           </div>
#           <div class="list__col list__col--occu">
#            <span>
#             Dnes
#            </span>
#           </div>
#           <div class="list__col list__col--occu">
#            <span>
#             Zítra
#            </span>
#           </div>
#           <div class="list__col list__col--occu">
#            <span>
#             Pozítří
#            </span>
#           </div>
#          </div>
#          <div class="list__result" id="#NaŽádanku.cz-–-Odběrové-centrum-Praha-15-(H.-Měcholupy)">
#           <a class="list__link" href="/Detail?id=a81a99e2-90bd-494c-ae42-7090f93115ca&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              #NaŽádanku.cz – Odběrové centrum Praha 15 (H. Měcholupy)
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="#Vyšetři.mě-–-Odběrové-centrum-Praha-15-(H.-Měcholupy)">
#           <a class="list__link" href="/Detail?id=42c85d23-21e4-4fe9-baef-9ab06c0cbe6d&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              #Vyšetři.mě – Odběrové centrum Praha 15 (H. Měcholupy)
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Volná kapacita" src="/Content/Images/mala.svg" title="Volná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Volná kapacita" src="/Content/Images/mala.svg" title="Volná kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="#Vyšetři.mě-–-Odběrové-centrum-Praha-6-(Ruzyně)">
#           <a class="list__link" href="/Detail?id=4bf34117-aadf-400d-91ec-77dc8633874f&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              #Vyšetři.mě – Odběrové centrum Praha 6 (Ruzyně)
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Volná kapacita" src="/Content/Images/mala.svg" title="Volná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Volná kapacita" src="/Content/Images/mala.svg" title="Volná kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AESKULAB---odběrové-místo-VIVO-Hostivař">
#           <a class="list__link" href="/Detail?id=e3bc023c-27a1-496f-8a5c-665b0e103e60&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AESKULAB - odběrové místo VIVO Hostivař
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AESKULAB-Praha-6---OM-poliklinika-DAM,-Brixiho">
#           <a class="list__link" href="/Detail?id=4e6f8c5e-1b70-4289-a2ab-ae9065304eb5&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AESKULAB Praha 6 - OM poliklinika DAM, Brixiho
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AESKULAB-Praha-8---Mazurská">
#           <a class="list__link" href="/Detail?id=5fe2de84-e229-4505-8cc3-4a7d11035228&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AESKULAB Praha 8 - Mazurská
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AESKULAB-Praha-Čs.exilu">
#           <a class="list__link" href="/Detail?id=3960f5a9-8269-487c-8b93-f1fee91346ce&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AESKULAB Praha Čs.exilu
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AESKULAB-Praha-Vajgarská">
#           <a class="list__link" href="/Detail?id=c8986ef2-a361-4830-9fc2-c301cae6dc2a&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AESKULAB Praha Vajgarská
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AKESO-holding---odběrové-místo-Praha-Černý-Most">
#           <a class="list__link" href="/Detail?id=2f2efdc8-63ea-4ab1-b6cd-9f39896ee2d8&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AKESO holding - odběrové místo Praha Černý Most
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AKESO-holding---odběrové-místo-Praha-Eden">
#           <a class="list__link" href="/Detail?id=755322f8-8f3d-4048-94d6-d01a39701638&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AKESO holding - odběrové místo Praha Eden
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AKESO-holding---odběrové-místo-Praha-Chlumecká">
#           <a class="list__link" href="/Detail?id=3c58898a-034a-4056-80c6-d3f14748f54c&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AKESO holding - odběrové místo Praha Chlumecká
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AKESO-holding---OM-Seydlerova,-Praha-5---Nové-Butovice-(Poliklinika-Lípa)">
#           <a class="list__link" href="/Detail?id=8c49206d-ff94-4183-a1eb-df190d9f345b&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AKESO holding - OM Seydlerova, Praha 5 - Nové Butovice (Poliklinika Lípa)
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AKESO-holding---OM-Stroupežnického,-Praha-5---Anděl">
#           <a class="list__link" href="/Detail?id=0d6a6d59-1ae7-43d8-8dc1-a8ecbb8a425c&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AKESO holding - OM Stroupežnického, Praha 5 - Anděl
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="AURUM-CLINIC-s.r.o.---odběrové-místo-Zborovská">
#           <a class="list__link" href="/Detail?id=5ecf72d5-b142-4aa6-aeef-0a93fd9370df&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              AURUM CLINIC s.r.o. - odběrové místo Zborovská
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Booster-event-s.r.o.---odběrové-místo-poliklinika-Štěchovická">
#           <a class="list__link" href="/Detail?id=2a479c5c-7a9a-4c1a-ba15-047afb9373e9&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Booster event s.r.o. - odběrové místo poliklinika Štěchovická
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Centrum-zdravotnického-zabezpečení-sportovní-reprezentace---OM-Strahov">
#           <a class="list__link" href="/Detail?id=f6f6b3b0-360b-40de-bf60-78beb7813464&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Centrum zdravotnického zabezpečení sportovní reprezentace - OM Strahov
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="CITYLAB-spol.-s-r.o.-Uhříněves---odběrové-místo">
#           <a class="list__link" href="/Detail?id=a9b735bb-9831-4604-98b7-3383b27415da&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              CITYLAB spol. s r.o. Uhříněves - odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="CovidPoint-ČSAP-z.s.---Praha-8,-Karlín">
#           <a class="list__link" href="/Detail?id=eb2cf89b-cebb-436b-b077-237bd99fd222&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              CovidPoint ČSAP z.s. - Praha 8, Karlín
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Česká-nemocniční-s.r.o.---odběrové-místo-DBK-Praha-4">
#           <a class="list__link" href="/Detail?id=6f349b55-669e-4ad3-8b38-2fc76e46b2f7&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Česká nemocniční s.r.o. - odběrové místo DBK Praha 4
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Dětská-ambulance,-Soukalova-3355/3,-Praha-12">
#           <a class="list__link" href="/Detail?id=3950fdb3-ae84-4e93-952e-4f19badc38f3&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Dětská ambulance, Soukalova 3355/3, Praha 12
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Dopravní-zdravotnictví-a.s.,-Poliklinika-AGEL-Praha">
#           <a class="list__link" href="/Detail?id=d91a2948-366c-40d2-a593-3358b8504f7b&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Dopravní zdravotnictví a.s., Poliklinika AGEL Praha
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="EliteMedical-s.r.o.---odběrové-místo">
#           <a class="list__link" href="/Detail?id=2c400476-462e-40da-be55-9bdd3a0d8b4c&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              EliteMedical s.r.o. - odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Elphogene-s.r.o.---odběrové-místo-Praha-Drnovská">
#           <a class="list__link" href="/Detail?id=f4d02b50-1561-4c7e-9cf4-8d85b2d985ea&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Elphogene s.r.o. - odběrové místo Praha Drnovská
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="EUC-Klinika-Praha-Kartouzská---odběrové-místo">
#           <a class="list__link" href="/Detail?id=2824c268-029c-4718-891d-82ab1a58c7a0&amp;backURL=/">
# ...
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Krajská-nemocnice-T.Bati,-a.-s.">
#           <a class="list__link" href="/Detail?id=83497f16-4abf-498a-9853-b7af4c65373a&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Krajská nemocnice T.Bati, a. s.
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Kroměřížská-nemocnice-a.s.">
#           <a class="list__link" href="/Detail?id=34c7c1cb-2367-41d5-b1ea-48209660a472&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Kroměřížská nemocnice a.s.
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Kroměřížská-nemocnice-a.s.---odběrové-místo-Výstaviště-Floria">
#           <a class="list__link" href="/Detail?id=8fbc61f7-4bc0-4f6e-b612-b219320ce737&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Kroměřížská nemocnice a.s. - odběrové místo Výstaviště Floria
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Městská-poliklinika-Otrokovice---odběrové-místo">
#           <a class="list__link" href="/Detail?id=5189d544-9318-4e95-9d98-03aa573ba664&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Městská poliklinika Otrokovice - odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Zavřeno" src="/Content/Images/ic_zavreno.svg" title="Zavřeno" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Mobilní-zdravotní-sestra---odběrové-místo-Valašské-Meziříčí">
#           <a class="list__link" href="/Detail?id=393fcc83-1f1d-413d-9e9f-752e246b4008&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Mobilní zdravotní sestra - odběrové místo Valašské Meziříčí
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Nemocnice-Valašské-Meziříčí---odběrové-místo">
#           <a class="list__link" href="/Detail?id=9b8effb3-fce5-4322-9bf1-40722ab0b898&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Nemocnice Valašské Meziříčí - odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Uherskohradišťská-nemocnice-a.-s.,-odběrové-místo">
#           <a class="list__link" href="/Detail?id=9831ca97-a7a5-42c0-9df5-e8b095e3ade7&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Uherskohradišťská nemocnice a. s., odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#              <img alt="Samoplátce" src="/Content/Images/ic_samoplatce.svg" title="Samoplátce" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="OM se připojuje" src="/Content/Images/ic_neznama-data.svg" title="OM se připojuje" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Vaše-laboratoře-s.r.o.,-Zlín---odběrové-místo">
#           <a class="list__link" href="/Detail?id=f09b46a0-acbe-4466-974e-377b64a2e215&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Vaše laboratoře s.r.o., Zlín - odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#          <div class="list__result" id="Vsetínská-nemocnice,-a.s.,-odběrové-místo">
#           <a class="list__link" href="/Detail?id=b84211a4-9c9e-4773-8439-71bb18fde2d4&amp;backURL=/">
#            <span class="list__col">
#             <span>
#              Vsetínská nemocnice, a.s., odběrové místo
#             </span>
#            </span>
#            <span class="list__col">
#             <span data-label="Příjem: ">
#              <img alt="S žádankou" src="/Content/Images/ic_zadanka.svg" title="S žádankou" width="24"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Dnes: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Zítra: ">
#              <img alt="Žádná kapacita" src="/Content/Images/velka.svg" title="Žádná kapacita" width="20"/>
#             </span>
#            </span>
#            <span class="list__col list__col--occu">
#             <span data-label="Pozítří: ">
#              <img alt="Omezená kapacita" src="/Content/Images/stredni.svg" title="Omezená kapacita" width="20"/>
#             </span>
#            </span>
#           </a>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <div class="footer">
#    <div class="footer__deco">
#     <span class="footer__bg-1">
#     </span>
#     <span class="footer__bg-2">
#     </span>
#     <span class="footer__bg-3">
#     </span>
#     <span class="footer__bg-4">
#     </span>
#     <span class="footer__bg-5">
#     </span>
#    </div>
#    <div class="section">
#     <div class="footer__top">
#      <a class="js-scroll" href="#nahoru">
#       <span>
#        Zpět nahoru
#       </span>
#      </a>
#     </div>
#     <div class="footer__logos">
#      <div class="footer__logo">
#       <a href="https://www.nakit.cz/">
#        <img alt="Národní agentura pro komunikační a informační technologie" src="/Content/Images/logo/nakit_gray.png" width="130"/>
#       </a>
#      </div>
#      <div class="footer__logo">
#       <a href="http://www.acr.army.cz/">
#        <img alt="Armáda ČR" src="/Content/Images/logo/acr.png" width="130"/>
#       </a>
#      </div>
#      <div class="footer__logo">
#       <a href="https://www.mzcr.cz/">
#        <img alt="Ministerstvo zdravotnictví České republiky" src="/Content/Images/logo/mzcr.svg" width="130"/>
#       </a>
#      </div>
#      <div class="footer__logo">
#       <a href="https://www.uzis.cz/">
#        <img alt="Ústav zdravotnických informací a statistiky ČR" src="/Content/Images/logo/uzis.svg" width="130"/>
#       </a>
#      </div>
#      <div class="footer__logo">
#       <a href="https://www.sator-it.com/">
#        <img alt="Sator IT Consulting" src="/Content/Images/logo/satorIT.png" width="130"/>
#       </a>
#      </div>
#     </div>
#     <div class="footer__bottom">
#      <p>
#       © 2020 Ministerstvo zdravotnictví ČR
#       <span class="footer__break">
#        |
#       </span>
#       <a href="/Accessibility">
#        Prohlášení o přístupnosti
#       </a>
#       <span class="footer__break">
#        |
#       </span>
#       <a href="https://www.uzis.cz/cookies">
#        Práce s cookie
#       </a>
#       <br/>
#       Závady můžete ohlásit na
#       <a href="mailto:crs-podpora@nakit.cz" title="Uveďte prosím do emailu název odběrného místa">
#        crs-podpora@nakit.cz
#       </a>
#       <span class="footer__break">
#        |
#       </span>
#       <a href="/Content/Images/CRS_Architektura.png" target="_blank">
#        Architektura systému
#       </a>
#      </p>
#     </div>
#    </div>
#   </div>
#   <script crossorigin="anonymous" integrity="sha384-b/U6ypiBEHpOf/4+1nzFpr53nxSS+GLCkfwBdFNTxtclqqenISfwAzpKaMNFNmj4" src="https://cdnjs.cloudflare.com/ajax/libs/popper.js/1.11.0/umd/popper.min.js">
#   </script>
#   <script src="/bundles/bootstrap?v=mScK3BTld_WCax2hi2Kbhu2SOoeAthuyst9eTvwLEdQ1">
#   </script>
#  </body>
# </html>
#
#
#
#
#
#
#
#
# U

# %%
for a in soup.find_all('a', class_ = "list_link", href=True):
    print ("Found the URL:", a['href'])

# %%
# Getting an unique identifier of each place - the id seems to be stored in href of <a> tag right after "?id="
# All obtained Ids are then assigned to TestCenterIds array

testingCenterHyperlinkTags = soup.find_all('a', class_ = "list__link", href=True)

TestCenterIds = []

for testingCenterHyperlinkTag in testingCenterHyperlinkTags[:5]:
    testingCenterHyperlink = testingCenterHyperlinkTag['href'][11:47]
    print ("Found the id:", testingCenterHyperlink)
    TestCenterIds.append(testingCenterHyperlink)

TestCenterIds[0:5]
# Out:
# Found the id: a81a99e2-90bd-494c-ae42-7090f93115ca
# Found the id: 42c85d23-21e4-4fe9-baef-9ab06c0cbe6d
# Found the id: 4bf34117-aadf-400d-91ec-77dc8633874f
# Found the id: e3bc023c-27a1-496f-8a5c-665b0e103e60
# Found the id: 4e6f8c5e-1b70-4289-a2ab-ae9065304eb5
# ['a81a99e2-90bd-494c-ae42-7090f93115ca',
#  '42c85d23-21e4-4fe9-baef-9ab06c0cbe6d',
#  '4bf34117-aadf-400d-91ec-77dc8633874f',
#  'e3bc023c-27a1-496f-8a5c-665b0e103e60',
#  '4e6f8c5e-1b70-4289-a2ab-ae9065304eb5']

# %% [markdown]
# The OOP structure should consist of following objects: Place, DateCapacity, Region. TestingPlace object is the main object in our project and in order to have all data consistent and in order, we will work with TestingPlace ID as an unique identifier instead of the Name.

# %%
# Defince Place class

class Place:
    
    def __init__(self, id, URL_address, region):
        self.id = id
        self.URL_address = URL_address
        self.region = region
    
    def basics(self):
        return f"TestingCapacity record with id {self.id} can be found at {self.URL_address}"

# %%
# Get all places the then for each Test Center Id try to find Place record with matchind Id. 
# If no such record found, create new Place record.

for PlaceId in TestCenterIds:
    pass

# %%
test_centers = soup.find_all('div', class_="list__result")
header = soup.find('div', class_="list__headline").text.strip()
print(f" Header: {header}") 

for test_center in test_centers:
    company_name = test_center.find('span', class_="list__col").text.replace('\n ', '')
    #callendar= test_center.find('div', class_="main")#.text.replace('\n ', '')
    print(f" Company Name : {company_name.strip()}")
   
    print(' ')
# Out:
# C Laboratoře Praha
#
#  Company Name : EUC Laboratoře s.r.o. - odběrové místo Praha Bohdalec
#
#  Company Name : EUC Laboratoře s.r.o. Horní Počernice - odběrové místo
#
#  Company Name : Fakultní nemocnice Královské Vinohrady
#
#  Company Name : Fakultní nemocnice v Motole
#
#  Company Name : Forenzní DNA servis s.r.o. - odběrové místo FN Bulovka
#
#  Company Name : GenDetective - Černý Most
#
#  Company Name : GenDetective - Čestlice
#
#  Company Name : GenDetective s.r.o. - odběrové místo Praha Kutnohorská
#
#  Company Name : GenDetective s.r.o. - odběrové místo Praha U Technoplynu
#
#  Company Name : GenDetective s.r.o.- odběrové místo SAPA
#
#  Company Name : GenDetective s.r.o.-odběrové místo Drive-In Braník
#
#  Company Name : GenDetective s.r.o.-odběrové místo Drive-In Zličín
#
#  Company Name : GenDetective s.r.o.-odběrové místo Hamr Záběhlice
#
#  Company Name : GenDetective s.r.o.-odběrové místo Karlovy lázně
#
#  Company Name : Genetická laboratoř sanatoria Pronatal s.r.o. - odběrové místo Zelený pruh
#
#  Company Name : GHC Genetics - PVA Letňany DRIVE-IN
#
#  Company Name : GHC Praha - odběrové místo Letiště Václava Havla
#
#  Company Name : GHC Praha Holešovice, odběrové místo
#
#  Company Name : GHC Praha Vítězné náměstí, odběrové místo
#
#  Company Name : GHC, Václavské náměstí, odběrové místo
#
#  Company Name : Home Care Promedica s.r.o. - odběrové místo Pod Višňovkou
#
#  Company Name : INTER CLINIC Praha Radotín - odběrové místo
#
#  Company Name : IVF CUBE
#
#  Company Name : Klinika GHC - odběrové místo Praha 1 Krakovská
#
#  Company Name : Laboratoře lékařské genetiky - Lovosická
#
#  Company Name : Medica JM s.r.o. - odběrové místo Kunratice
#
#  Company Name : Medica JM s.r.o. - Poliklinika Michnova
#
#  Company Name : Medical Testing s.r.o. - Arkalycká
#
#  Company Name : Medical testing s.r.o. - odběrové místo centrum Radotín
#
#  Company Name : Medical testing s.r.o. - odběrové místo FASHION ARÉNA Štěrboholy
#
#  Company Name : Medical testing s.r.o. - odběrové místo Náplavka Čechův most
#
#  Company Name : Medical testing s.r.o. - odběrové místo Praha 11 Kaplanova
#
#  Company Name : Medical testing s.r.o. - odběrové místo Praha 8 Žernosecká
#
#  Company Name : Medical testing s.r.o. - odběrové místo Praha 9 Kovanecká
#
#  Company Name : MEDICAL TESTING s.r.o. - odběrové místo Praha Hořejší nábřeží
#
#  Company Name : Medical testing s.r.o. - odběrové místo Stodůlky EGLO
#
#  Company Name : Medical testing s.r.o. - odběrové místo Zbraslav
#
#  Company Name : Medicínské centrum Praha - Odběrové místo
#
#  Company Name : Medidental - Kytlická
#
#  Company Name : Městská poliklinika Praha - odběrové místo Mariánské nám
#
#  Company Name : Městská poliklinika Praha - odběrové místo Spálená
#
#  Company Name : Nemocnice na Bulovce
#
#  Company Name : Nemocnice Na Františku - odběrové místo
#
#  Company Name : NutriMed Lab s.r.o. - odběrové místo Libeň
#
#  Company Name : Ordinace Ruzyně s.r.o. - odběrové místo Centrum Černý Most
#
#  Company Name : Ordinace Ruzyně s.r.o. - odběrové místo Centrum Chodov
#
#  Company Name : Ordinace Ruzyně s.r.o. - odběrové místo Čakovice
#
#  Company Name : Ordinace Ruzyně s.r.o. - odběrové místo Smíchov
#
#  Company Name : Ordinace Ruzyně s.r.o., odběrové místo Chodov
#
#  Company Name : Poliklinika Chomutovská
#
#  Company Name : Poliklinika Praha Stodůlky - odběrové místo
#
#  Company Name : PREVEDIG medical - ČZU Suchdol
#
#  Company Name : PREVEDIG medical - Pražská tržnice
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo
#
#  Company Name : PREVEDIG medical, s.r.o. - odběrové místo FLORA Praha 3
#
#  Company Name : PREVEDIG medical, s.r.o. - odběrové místo Futurama Praha 8
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Havlíčkovo náměstí
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Jedenáctka
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Pelléova Praha 6
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Revoluční
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Šutka
#
#  Company Name : SALUBRITA
#
#  Company Name : Scimed Biotechnologies, s.r.o. - odběrové místo
#
#  Company Name : Scimed Biotechnologies, s.r.o. - odběrové místo Praha Lidická
#
#  Company Name : SPADIA LAB, a.s. - Praha  Žluté lázně
#
#  Company Name : SYNLAB Praha Bělohorská - odběrové místo
#
#  Company Name : SYNLAB Praha CUBE Evropská - odběrové místo
#
#  Company Name : SYNLAB Praha Zbraslav - odběrové místo
#
#  Company Name : The clinic medical s.r.o - odběrové místo
#
#  Company Name : Thomayerova nemocnice, odběrové místo
#
#  Company Name : Urogyn Medico s.r.o. - odběrové místo
#
#  Company Name : Ústřední vojenská nemocnice
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Rajská zahrada
#
#  Company Name : Všeobecná fakultní nemocnice v Praze - odběrové místo
#
#  Company Name : Zotavovna VS ČR - odběrové místo Na Květnici
#
#  Company Name : AESKULAB České Budějovice
#
#  Company Name : CITYLAB spol. s r.o. - odběrové místo Milevsko
#
#  Company Name : CITYLAB spol. s r.o. České Budějovice
#
#  Company Name : EUC Laboratoře - odběrové místo poliklinika České Budějovice
#
#  Company Name : GEN-TREND s.r.o. - odběrové místo Rudolfov
#
#  Company Name : HP Strážný na silnici I/4 - Scimed
#
#  Company Name : Klinické laboratoře Tábor - odběrové místo
#
#  Company Name : Nemocnice České Budějovice - Odběrové místo
#
#  Company Name : Nemocnice Český Krumlov, a.s.
#
#  Company Name : Nemocnice Jindřichův Hradec
#
#  Company Name : Nemocnice Písek, a.s. - Odběrové místo
#
#  Company Name : Nemocnice Prachatice
#
#  Company Name : Nemocnice Strakonice
#
#  Company Name : Nemocnice Tábor - Odběrové místo
#
#  Company Name : Nextclinics České budějovice
#
#  Company Name : SYNLAB České Budějovice U tří lvů - odběrové místo
#
#  Company Name : SYNLAB České Budějovice Vrbenská - odběrové místo
#
#  Company Name : SYNLAB Český Krumlov - odběrové místo
#
#  Company Name : SYNLAB Písek - odběrové místo Drlíčov
#
#  Company Name : AG COVID POINT - odběrové místo OC Královo Pole
#
#  Company Name : AG Point OC Olympie Brno
#
#  Company Name : BEZ KAZU s.r.o.
#
#  Company Name : Covid Spot, Kolejní, 612 00 Brno - Královo Pole
#
#  Company Name : Cytogenetická laboratoř Brno, s.r.o. - odběrové místo
#
#  Company Name : ELISABETH PHARMACON, spol. s r. o. - Odběrové místo
#
#  Company Name : Fakultní nemocnice Brno Bohunice
#
#  Company Name : Fakultní nemocnice Brno Bohunice - dětská nemocnice
#
#  Company Name : Fakultní nemocnice u Sv. Anny v Brně, odběrové místo
#
#  Company Name : Hola Biolabs s.r.o. - odběrové místo Brno Heršpická
#
#  Company Name : Hola Biolabs s.r.o. - odběrové místo Brno Zvonařka
#
#  Company Name : Hola Biolabs s.r.o. - odběrové místo poliklinika Starý Lískovec
#
#  Company Name : IFCOR Brno
#
#  Company Name : Medical testing s.r.o. - odběrové místo Brno Dobrovského
#
#  Company Name : Medical testing s.r.o. - odběrové místo Brno Trnitá
#
#  Company Name : MEDICINECARE s.r.o. - odběrové místo Brno - Veselá
#
#  Company Name : MeDiLa spol. s r.o., odběrové centrum Brno Lesná, Halasov - odběrové místo
#
#  Company Name : Nemocnice Blansko - odběrové místo
#
#  Company Name : Nemocnice Boskovice, s.r.o. - odběrové místo
#
#  Company Name : Nemocnice Břeclav
#
#  Company Name : Nemocnice Ivančice, p.o. - odběrové místo
#
#  Company Name : Nemocnice Kyjov - odběrové místo
#
#  Company Name : Nemocnice milosrdných bratří Brno - odběrové místo
#
#  Company Name : Nemocnice TGM Hodonín, p. o., odběrové místo
#
#  Company Name : Nemocnice Tišnov
#
#  Company Name : Nemocnice Vyškov, p.o. - odběrové místo
#
#  Company Name : Nemocnice Znojmo, p. o. - Odběrové místo
#
#  Company Name : Oblastní spolek Českého červeného kříže - odběrové místo Blansko
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Brno
#
#  Company Name : SPADIA LAB, a.s. - BRNO Veveří
#
#  Company Name : SYNLAB Brno Tuřany - mobilní odběrové místo letiště
#
#  Company Name : Františkovy Lázně AQUAFORUM a.s.
#
#  Company Name : HP na silnici na I/6 Pomezí nad Ohří - Scimed
#
#  Company Name : Karlovarská krajská nemocnice a.s.
#
#  Company Name : Karlovarská krajská nemocnice a.s., nemocnice Cheb
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Sokolov
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Kraslice
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Nejdek
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Ostrov
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Aš
#
#  Company Name : Lab In - Institut laboratorní medicíny Karlovy Vary - odběrové místo
#
#  Company Name : LabIn - institut laboratorní medicíny - odběrové místo Mariánské lázně
#
#  Company Name : Léčebné lázně Mariánské Lázně a.s. - odběrové místo Villa Butterfly
#
#  Company Name : NZZ Garant-Service group
#
#  Company Name : PREVEDIG medical - Sokolov
#
#  Company Name : 11 OT AČR
#
#  Company Name : Fakultní nemocnice Hradec Králové - Odběrové místo
#
#  Company Name : MeDiLa spol. s r.o., odběrové místo Hradec Králové
#
#  Company Name : Městská nemocnice a.s., Dvůr Králové nad Labem
#
#  Company Name : Oblastní nemocnice Jičín, a.s.
#
#  Company Name : Oblastní Nemocnice Náchod a.s., nemocnice Náchod
#
#  Company Name : Oblastní Nemocnice Náchod a.s., nemocnice Rychnov nad Kněžnou
#
#  Company Name : Oblastní nemocnice Trutnov
#
#  Company Name : Odběrové místo Scimed
#
#  Company Name : SYNLAB Hradec Králové - mobilní odběrové místo letiště
#
#  Company Name : GenDetective s.r.o. - odběrové místo Liberec
#
#  Company Name : Krajská nemocnice Liberec, a.s. - Odběrové místo
#
#  Company Name : MeDiLa spol. s r.o., odběrové místo Turnov zimní stadion
#
#  Company Name : MMN, a.s., nemocnice Jilemnice
#
#  Company Name : MMN, a.s., nemocnice Semily - odběrové místo
#
#  Company Name : Nemocnice Česká Lípa - Odběrové místo
#
#  Company Name : Nemocnice Jablonec nad Nisou, p.o.
#
#  Company Name : SYNLAB Liberec - mobilní odběrové místo
#
#  Company Name : Zdravotní ústav se sídlem v Ústí nad Labem - Odběrové místo Liberec
#
#  Company Name : Ambulance Pacanovský s.r.o. - odběrové místo Ostrava Poruba
#
#  Company Name : Bílovecká nemocnice
#
#  Company Name : Bohumínská městská nemocnice, a.s.
#
#  Company Name : CGB laboratoř a.s. - odběrové místo Ostrava Opavská
#
#  Company Name : Fakultní nemocnice Ostrava
#
#  Company Name : Lázně Darkov, a.s
#
#  Company Name : Městská nemocnice Ostava - Fifejdy PCR
#
#  Company Name : Nemocnice AGEL Bruntál - odběrové místo
#
#  Company Name : Nemocnice AGEL Český Těšín
#
#  Company Name : Nemocnice Nový Jičín, a. s.
#
#  Company Name : Nemocnice s poliklinikou Havířov, p.o.
#
#  Company Name : Nemocnice s poliklinikou Karviná, p. o.
#
#  Company Name : Nemocnice Třinec, p.o.
#
#  Company Name : Nemocnice ve Frýdku-Místku, p.o.
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Ostrava
#
#  Company Name : Sdružené zdravotnické zařízení Krnov, p.o.
#
#  Company Name : Slezská nemocnice v Opavě, p.o.
#
#  Company Name : SPADIA LAB, a.s. -  Frýdek-Místek
#
#  Company Name : SPADIA LAB, a.s. -  Ostrava
#
#  Company Name : SPADIA LAB, a.s. - odběrové místo Nový Jičín
#
#  Company Name : SYNLAB Ostrava - Ostravar Aréna
#
#  Company Name : Vítkovická nemocnice
#
#  Company Name : Zdravotní ústav se sídlem v Ostravě
#
#  Company Name : AGEL Středomoravská nemocniční a.s., Nemocnice AGEL Prostějov
#
#  Company Name : AGEL Středomoravská nemocniční a.s., Nemocnice AGEL Přerov
#
#  Company Name : AGEL Středomoravská nemocniční a.s., Nemocnice AGEL Šternberk
#
#  Company Name : EMA Emergency s.r.o. - odběrové místo Olomouc Šantovka
#
#  Company Name : Fakultní nemocnice Olomouc - Odběrové místo
#
#  Company Name : Jesenická nemocnice a.s.
#
#  Company Name : Nemocnice Hranice a.s.
#
#  Company Name : Nemocnice Šumperk a.s. - Odběrové místo
#
#  Company Name : Odběrové centrum Rapid Samotišky
#
#  Company Name : Vojenská nemocnice Olomouc
#
#  Company Name : EUC Laboratoře - odběrové místo Sportcentrum Vysoké Mýto
#
#  Company Name : Chrudimská nemocnice
#
#  Company Name : Laboratoře lékařské genetiky
#
#  Company Name : Litomyšlská nemocnice - Odběrové místo
#
#  Company Name : MeDiLa spol. s r. o.
#
#  Company Name : ORL ambulance TINITUS s.r.o. - odběrové místo Chrudim
#
#  Company Name : Pardubická nemocnice - Odběrové místo
#
#  Company Name : AKESO holding - odběrové místo Plzeň Stavební
#
#  Company Name : Bioptická laboratoř, s.r.o., Plzeň
#
#  Company Name : Domažlická nemocnice, a.s.
#
#  Company Name : Dopravní zdravotnictví a.s., Poliklinika AGEL Plzeň
#
#  Company Name : Elphogene s.r.o. - odběrové místo Stříbro
#
#  Company Name : Fakultní nemocnice Plzeň
#
#  Company Name : GenDetective s.r.o. - odběrové místo Plzeň
#
#  Company Name : HP Rozvadov - Scimed
#
#  Company Name : HP Rozvadov - Záchranná služba ASČR
#
#  Company Name : HP Železná Ruda
#
#  Company Name : Klatovská nemocnice, a.s. - Odběrové místo
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Dobřany
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Přeštice
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Tachov
#
#  Company Name : Nemocnice Privamed - odběrové místo
#
#  Company Name : Nemocnice Sušice
#
#  Company Name : Nextclinics Plzeň
#
#  Company Name : Rokycanská nemocnice, a.s.
#
#  Company Name : Stodská nemocnice, a.s., odběrové místo
#
#  Company Name : SYNLAB Plzeň - odběrové místo Majerova
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Plzeň
#
#  Company Name : Zubní s.r.o., Odběrové místo Plzeň NC Borská Pole - odběrové místo
#
#  Company Name : CITYLAB spol. s r.o. - odběrové místo Benátky nad Jizerou
#
#  Company Name : CITYLAB spol. s r.o. - odběrové místo Kutná Hora Čáslavská
#
#  Company Name : CITYLAB spol. s r.o. - odběrové místo Mnichovo Hradiště
#
#  Company Name : CITYLAB spol. s r.o. - odběrové místo Říčany
#
#  Company Name : COP Plus s.r.o. - odběrové místo Tuchoměřice
#
#  Company Name : Česká Laboratorní s.r.o. - OM Český Brod
#
#  Company Name : GenDetective - Mladá Boleslav
#
#  Company Name : GenDetective s.r.o. - odběrové místo Benešov
#
#  Company Name : GenDetective s.r.o. - odběrové místo Brandýs nad Labem
#
#  Company Name : GenDetective s.r.o. - odběrové místo Příbram
#
#  Company Name : GenDetective s.r.o. - odběrové místo Vlašim
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Kladno
#
#  Company Name : Lázně FELICITAS s.r.o. - odběrové místo
#
#  Company Name : Lékárna ve Voticích s.r.o. - odběrové místo Komenského nám.
#
#  Company Name : Masarykova nemocnice Rakovník
#
#  Company Name : Medica JM s.r.o. - Odběrné místo Hostivice
#
#  Company Name : Medica JM s.r.o.- Poliklinika Čtyřobvod
#
#  Company Name : Medical service DAVEPO s.r.o. - odběrové místo
#
#  Company Name : Medical testing s.r.o. - odběrové místo centrum Průhonice
#
#  Company Name : Medical testing s.r.o. - odběrové místo Jesenice
#
#  Company Name : Medidental s.r.o. - odběrové místo Neratovice
#
#  Company Name : Mělnická zdravotní, a.s. - odběrové místo
#
#  Company Name : Městská nemocnice Čáslav
#
#  Company Name : Nemocnice AGEL Říčany
#
#  Company Name : Nemocnice Hořovice - odběrové místo
#
#  Company Name : Nemocnice Hořovice - odběrové místo Beroun
#
#  Company Name : Nemocnice Nymburk - odběrové místo
#
#  Company Name : Nemocnice Rudolfa a Stefanie Benešov, a.s.
#
#  Company Name : Nemocnice Slaný - odběrové místo
#
#  Company Name : NL-BioLAB Letiště Praha - mobilní odběrové místo
#
#  Company Name : NutriMed Lab s.r.o. - odběrové místo Kralupy nad Vltavou
#
#  Company Name : Oblastní nemocnice Kolín, a.s. - Odběrové místo
#
#  Company Name : Oblastní nemocnice Kolín, a.s., Nemocnice Kutná Hora
#
#  Company Name : Oblastní nemocnice Mladá Boleslav, a.s.  - Odběrové místo
#
#  Company Name : Oblastní nemocnice Příbram, a.s. - Odběrové místo
#
#  Company Name : ON Kladno, a.s., nem. SČK
#
#  Company Name : Ordinace Ruzyně s.r.o. - odběrové místo Příbram
#
#  Company Name : Ordinace Ruzyně s.r.o., odběrové místo Vestec
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Libiš
#
#  Company Name : RESCUE HELP - ZDRAVOTNICKÁ SLUŽBA, z.s. - odběrové místo Černuc
#
#  Company Name : Scimed Biotechnologies, s.r.o. - odběrové místo Kladno
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Mělník
#
#  Company Name : Zubní s.r.o. - odběrové místo Brandýs nad Labem
#
#  Company Name : AESKULAB Louny
#
#  Company Name : AESKULAB Teplice
#
#  Company Name : Děčín Parkoviště u Viaduktu
#
#  Company Name : GenDetective s.r.o.- odběrové místo Drive in Most
#
#  Company Name : GenDetective s.r.o.- odběrové místo Drive in Teplice
#
#  Company Name : HP na D8 Krásný Les/Libouchec
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Klášterec nad Ohří
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Jirkov
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Louny
#
#  Company Name : Lab In - Institut laboratorní medicíny - odběrové místo Most
#
#  Company Name : Laboratoře Diagnostika s. r. o.
#
#  Company Name : Lázně Teplice v Čechách a.s. - odběrové místo Rooseveltova
#
#  Company Name : Masarykova nemocnice v Ústí nad Labem, o. z.
#
#  Company Name : MUDr. Miloš Hakl - odběrové místo Teplice Krupská
#
#  Company Name : MUDr. Vratislav Prejzek s.r.o.
#
#  Company Name : Nemocnice Děčín, o. z.
#
#  Company Name : Nemocnice Chomutov, o. z.
#
#  Company Name : Nemocnice Kadaň s.r.o. - odběrové místo
#
#  Company Name : Nemocnice Litoměřice, a.s.
#
#  Company Name : Nemocnice Most, o. z.
#
#  Company Name : Nemocnice Rumburk
#
#  Company Name : Nemocnice Teplice, o. z.
#
#  Company Name : Nemocnice Žatec, o.p.s.
#
#  Company Name : Nextclinics Štětí
#
#  Company Name : OKB Lab a.s. - odběrové místo Litvínov
#
#  Company Name : OKB Lab a.s. - odběrové místo poliklinika Bílina
#
#  Company Name : OKB Lab a.s. - odběrové místo Ústí nad Labem
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Krupka - Maršov
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Teplice
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Ústí nad Labem
#
#  Company Name : SYNLAB Jirkov - odběrové místo
#
#  Company Name : Teplice - Trnovany MUDr. Košťál - odběrové místo Masarykova třída
#
#  Company Name : VIDIA DIAGNOSTIKA, odběrové místo Děčín
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Chomutov
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Litoměřice
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Litvínov
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Most
#
#  Company Name : VIDIA-DIAGNOSTIKA, spol. s r.o - odběrové místo Ústí nad Labem
#
#  Company Name : Zdravotní ústav se sídlem v Ústí nad Labem
#
#  Company Name : IFCOR Jihlava - odběrové místo
#
#  Company Name : Medical testing s.r.o. - odběrové místo Jihlava Křížová
#
#  Company Name : MeDiLa spol. s r.o., odběrové místo Drive-in Žďár nad Sázavou - odběrové místo
#
#  Company Name : Nemocnice Havlíčkův Brod, příspěvková organizace
#
#  Company Name : Nemocnice Jihlava, příspěvková organizace
#
#  Company Name : Nemocnice Nové Město na Moravě p.o. - Odb.místo
#
#  Company Name : Nemocnice Pelhřimov, příspěvková organizace
#
#  Company Name : Nemocnice Třebíč, CL
#
#  Company Name : PREVEDIG medical, s.r.o. - Odběrové místo Jihlava
#
#  Company Name : Renturi s.r.o. - odběrové místo STOP SHOP Třebíč
#
#  Company Name : AKESO holding - odběrové místo Zlín
#
#  Company Name : EMA Emergency,s.r.o. - OC Centro Zlín-Malenovice
#
#  Company Name : IFCOR Uherské Hradiště - odběrové místo
#
#  Company Name : Krajská nemocnice T.Bati, a. s.
#
#  Company Name : Kroměřížská nemocnice a.s.
#
#  Company Name : Kroměřížská nemocnice a.s. - odběrové místo Výstaviště Floria
#
#  Company Name : Městská poliklinika Otrokovice - odběrové místo
#
#  Company Name : Mobilní zdravotní sestra - odběrové místo Valašské Meziříčí
#
#  Company Name : Nemocnice Valašské Meziříčí - odběrové místo
#
#  Company Name : Uherskohradišťská nemocnice a. s., odběrové místo
#
#  Company Name : Vaše laboratoře s.r.o., Zlín - odběrové místo
#
#  Company Name : Vsetínská nemocnice, a.s., odběrové místo

# %%
header = soup.find('div', class_="list__headline").text.strip()
header# in order to check how many free places are available
# Out:
# 'Hlavní město Praha (Počet OM: 102 - V následujících 3 dnech volná/celková kapacita: 18662 / 24179)'

# %% [markdown]
# Getting info about the website

# %%
import pandas as pd # to be saved and aggreagated into datafame
import numpy as np

# %%
#Getting tqdm in order to show a progress bar
from tqdm import tqdm_notebook as tqdm

# %%
def get_page_links(url):# Firstly created the function gets the data and returns the links of the each company 
    sleep(0.2) 
    base_url='https://testovani.uzis.cz/'
    r = requests.get(url)
    soup= BeautifulSoup(r.text,'lxml')
    links=soup.select('div.list__result a')
    return[ base_url + link.attrs['href'] for link in links]

# %%
    
def test_locatio_detail(url): # Created the second function which grabs all necessary information form each comapny and returns
    r = requests.get(url)
    soup= BeautifulSoup(r.text,'lxml')
    company_details={
        'Name':soup.select_one('div.detail__main h1').text.strip().replace('\n',' '),
        'Adress':soup.select_one('div.info td:nth-child(2)').text.strip().replace('\n',''),
        'Upřesnění polohy':soup.select_one('div.info :nth-child(2) td:nth-child(2)').text.strip().replace('\n',''),
        'Telefon':soup.select_one('div.info a').text.strip().replace('\n',''),
        'Poznámka':soup.select_one('div.info :nth-child(4) td:nth-child(2)').text.strip().replace('\n',''),
        'Příjem':soup.select_one('div.info :nth-child(5) td:nth-child(2)').text.strip().replace('\n',''),
        'Cena za samoodběř':soup.select_one('div.info :nth-child(6) td:nth-child(2)').text.strip().replace('\n',''),
        'Způsob rezervace':soup.select_one('div.info :nth-child(7) td:nth-child(2)').text.strip().replace('\n',''),
        'Odkaz na rezervační systém':soup.select_one('div.info :nth-child(8) td:nth-child(2)').text.strip().replace('\n',''),
        'DRIVE-IN':soup.select_one('div.info :nth-child(9) td:nth-child(2)').text.strip().replace('\n',''),
        #'Av_days':pd.DataFrame([soup.select_one('div.opening').text.strip().replace('\n','')])
   
    }
    #print(company_details)    
    return company_details
#test_location_detail('https://testovani.uzis.cz//Detail?id=b84211a4-9c9e-4773-8439-71bb18fde2d4&backURL')

# %%
#get_page_links("https://testovani.uzis.cz/")    

def main():# Created 3rd function which focuses on gattering all the information into one dictionary, to be saved in main function
   results=[]
   urls= get_page_links('https://testovani.uzis.cz/')
   comp_info=[test_locatio_detail(url) for url in tqdm(urls)]
   results.append(comp_info) #creating the data storage for further use, as we assume to use the callendar sting
   return results

   print(results)

# %%
print(main()) #Just for control, otherwise "messy" JSON taking up too much space

# %%
def test_locatio_detail(url): # Created the second function which grabs all necessary information form each company and returns
    r = requests.get(url)
    soup= BeautifulSoup(r.text,'lxml')
    company_details={
        'Name':soup.select_one('div.detail__main h1').text.strip().replace('\n',' '),
        'Address':soup.select_one('div.info td:nth-child(2)').text.strip().replace('\n',''),
        'Upřesnění polohy':soup.select_one('div.info :nth-child(2) td:nth-child(2)').text.strip().replace('\n',''),
        'Telefon':soup.select_one('div.info a').text.strip().replace('\n',''),
        'Poznámka':soup.select_one('div.info :nth-child(4) td:nth-child(2)').text.strip().replace('\n',''),
        'Příjem':soup.select_one('div.info :nth-child(5) td:nth-child(2)').text.strip().replace('\n',''),
        'Cena za samoodběr':soup.select_one('div.info :nth-child(6) td:nth-child(2)').text.strip().replace('\n',''),
        'Způsob rezervace':soup.select_one('div.info :nth-child(7) td:nth-child(2)').text.strip().replace('\n',''),
        'Odkaz na rezervační systém':soup.select_one('div.info :nth-child(8) td:nth-child(2)').text.strip().replace('\n',''),
        'DRIVE-IN':soup.select_one('div.info :nth-child(9) td:nth-child(2)').text.strip().replace('\n',''),
        #'Av_days':pd.DataFrame([soup.select_one('div.opening').text.strip().replace('\n','')])
   
    }
    #print(company_details)    
    return company_details
f=test_locatio_detail('https://testovani.uzis.cz//Detail?id=b84211a4-9c9e-4773-8439-71bb18fde2d4&backURL')
pd.DataFrame(f,index=['1',])
# Out:
#                                         Name                        Address  \
# 1  Vsetínská nemocnice, a.s., odběrové místo  Nemocniční 955, 755 01 Vsetín
#
#      Upřesnění polohy    Telefon  \
# 1  infekční ambulance  571818384
#
#                                             Poznámka  \
# 1  PCR testy - odběrové centrum - Infekční ambula...
#
#                               Příjem Cena za samoodběr  \
# 1  Osoby se žádánkou (od lékaře/KHS)
#
#          Způsob rezervace Odkaz na rezervační systém DRIVE-IN
# 1  online webová aplikace            nemocnice-vs.cz       Ne

# %% [markdown]
# Cleaned and used the previous main function to set structured data.

# %%
def main():# Created 3rd function which focuses on gattering all the information into one dictionary, to be saved in main function
   #results=[]
   urls= get_page_links('https://testovani.uzis.cz/')
   comp_info=pd.DataFrame([test_locatio_detail(url) for url in tqdm(urls)])
   #results.append(comp_info)
   return comp_info

main()
# Out:
# <ipython-input-18-29c69cb3d68c>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   comp_info=pd.DataFrame([test_locatio_detail(url) for url in tqdm(urls)])
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=351.0), HTML(value='')))
#                                                   Name  \
# 0    #NaŽádanku.cz – Odběrové centrum Praha 15 (H. ...
# 1    #Vyšetři.mě – Odběrové centrum Praha 15 (H. Mě...
# 2      #Vyšetři.mě – Odběrové centrum Praha 6 (Ruzyně)
# 3              AESKULAB - odběrové místo VIVO Hostivař
# 4       AESKULAB Praha 6 - OM poliklinika DAM, Brixiho
# ..                                                 ...
# 346  Mobilní zdravotní sestra - odběrové místo Vala...
# 347       Nemocnice Valašské Meziříčí - odběrové místo
# 348  Uherskohradišťská nemocnice a. s., odběrové místo
# 349      Vaše laboratoře s.r.o., Zlín - odběrové místo
# 350          Vsetínská nemocnice, a.s., odběrové místo
#
#                                                Address  \
# 0    Park na křižovatce ulic Ravennská a Milánská, ...
# 1    Park na křižovatce ulic Ravennská a Milánská, ...
# 2             Drnovská 1112/60 161 00 Praha 6 - Ruzyně
# 3                           Praha 10, Švehlova 1391/32
# 4             Brixiho 1968/1, 162 00 Praha 6 - Břevnov
# ..                                                 ...
# 346       Zdeňka Fibicha 287, 757 01 Valašské Meziříčí
# 347         U Nemocnice 980, 757 01, Valašské Meziříčí
# 348         J. E. Purkyně 365, 686 06 Uherské Hradiště
# 349                                   Tř. T. Bati 3910
# 350                      Nemocniční 955, 755 01 Vsetín
#
#                                       Upřesnění polohy        Telefon  \
# 0    Zelené oplocení v parku na křižovatce ulic Rav...  +420774605535
# 1    Zelené oplocení v parku na křižovatce ulic Rav...  +420771156107
# 2    Příjezdová cesta zezadu budovy (naproti adrese...  +420771156107
# 3        Odběrové místo - OC VIVO Hostivař, parkoviště  +420800737383
# 4    Poliklinika DAM, samostatný vchod vpravo z Bri...      800737383
# ..                                                 ...            ...
# 346
# 347                 odběrové centrum - poblíž vrátnice      571758605
# 348                                    areál nemocnice      724631022
# 349                              po levé straně budovy      739408931
# 350                                 infekční ambulance      571818384
#
#                                               Poznámka  \
# 0    Provádíme jak Antigenní testy jednou za 7 dnů ...
# 1    Rezervaci je nutno provést na webových stránká...
# 2    Rezervaci je nutno provést na webových stránká...
# 3
# 4
# ..                                                 ...
# 346
# 347  ODBĚROVÉ CENTRUM (OC) - nachází se vedle antig...
# 348  PCR - testy: nákladní brána, v části budovy A-...
# 349
# 350  PCR testy - odběrové centrum - Infekční ambula...
#
#                                 Příjem Cena za samoodběr  \
# 0    Osoby se žádánkou (od lékaře/KHS)
# 1       Osoby se žádankou i samoplátce
# 2       Osoby se žádankou i samoplátce
# 3       Osoby se žádankou i samoplátce
# 4       Osoby se žádankou i samoplátce
# ..                                 ...               ...
# 346
# 347     Osoby se žádankou i samoplátce
# 348     Osoby se žádankou i samoplátce
# 349  Osoby se žádánkou (od lékaře/KHS)
# 350  Osoby se žádánkou (od lékaře/KHS)
#
#                       Způsob rezervace Odkaz na rezervační systém DRIVE-IN
# 0    Přes webové stránky na přesný čas           www.nazadanku.cz       Ne
# 1                  Přes webové stránky             www.vysetri.me       Ne
# 2                  Přes webové stránky             www.vysetri.me      Ano
# 3            www.rezervace.aeskulab.cz      rezervace.aeskulab.cz       Ne
# 4                  Přes webové stránky      rezervace.aeskulab.cz       Ne
# ..                                 ...                        ...      ...
# 346                        telefonicky                                  Ne
# 347           Pro samoplátce – on-line             www.agellab.cz       Ne
# 348                Přes webové stránky         ambulance.nemuh.cz       Ne
# 349                         Reservatic             reservatic.com       Ne
# 350             online webová aplikace            nemocnice-vs.cz       Ne
#
# [351 rows x 10 columns]

# %%
df=main()
# Out:
# <ipython-input-18-29c69cb3d68c>:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   comp_info=pd.DataFrame([test_locatio_detail(url) for url in tqdm(urls)])
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=351.0), HTML(value='')))

# %%
df.to_csv('Covid.csv')

# %% [markdown]
# We will next load the data to our working directory to process the data clean and put it in commercially friendly way

# %%
data = pd.read_csv('Covid.csv', index_col = 0)
data.head(10)
# Out:
#                                                 Name  \
# 0  #NaŽádanku.cz – Odběrové centrum Praha 15 (H. ...
# 1  #NaŽádanku.cz – Odběrové centrum Praha 6 (Ruzyně)
# 2  #Vyšetři.mě – Odběrové centrum Praha 15 (H. Mě...
# 3    #Vyšetři.mě – Odběrové centrum Praha 6 (Ruzyně)
# 4            AESKULAB - odběrové místo VIVO Hostivař
# 5                        AESKULAB Praha 8 - Mazurská
# 6                            AESKULAB Praha Čs.exilu
# 7                           AESKULAB Praha Vajgarská
# 8  AKESO holding - OM Chlumecká, Praha 9 - Černý ...
# 9  AKESO holding - OM Jeremiášova, Praha 5 - Stod...
#
#                                               Adress  \
# 0  Park na křižovatce ulic Ravennská a Milánská, ...
# 1           Drnovská 1112/60 161 00 Praha 6 - Ruzyně
# 2  Park na křižovatce ulic Ravennská a Milánská, ...
# 3           Drnovská 1112/60 161 00 Praha 6 - Ruzyně
# 4                         Praha 10, Švehlova 1391/32
# 5             Mazurská 484/2, 181 00 Praha 8 - Troja
# 6                         Čs.exilu 2175/36, Praha 12
# 7                            Vajgarská 1141, Praha 9
# 8        Chlumecká 2420, Praha 9, Černý Most, 198 29
# 9      Jeremiášova 947/16, 155 00 Praha 5 - Stodůlky
#
#                                     Upřesnění polohy       Telefon  \
# 0  Zelené oplocení v parku na křižovatce ulic Rav...  4.207746e+11
# 1  Příjezdová cesta zezadu budovy (naproti adrese...  4.207746e+11
# 2  Zelené oplocení v parku na křižovatce ulic Rav...  4.207712e+11
# 3  Příjezdová cesta zezadu budovy (naproti adrese...  4.207712e+11
# 4      Odběrové místo - OC VIVO Hostivař, parkoviště           NaN
# 5                    Parkoviště polikliniky Mazurská  8.007374e+08
# 6                                                NaN  4.208007e+11
# 7                                                NaN  4.208007e+11
# 8              Parkoviště u vstupu do Sconto nábytek  4.207251e+11
# 9              Parkoviště u vstupu do Sconto nábytek  4.207251e+11
#
#                                             Poznámka  \
# 0                                                NaN
# 1                                                NaN
# 2  POZOR! Nově nás najdete v parku na křižovatce ...
# 3  Aktuálně testujeme pouze na přímý výskyt labor...
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7          Na místě možno platit kartou nebo hotově.
# 8  Odběr není možný bez předchozího objednání!\rR...
# 9  Odběr není možný bez předchozího objednání!\rR...
#
#                               Příjem  Cena za samoodběř  \
# 0  Osoby se žádánkou (od lékaře/KHS)                NaN
# 1  Osoby se žádánkou (od lékaře/KHS)                NaN
# 2                         Samoplátce                NaN
# 3                         Samoplátce                NaN
# 4     Osoby se žádankou i samoplátce                NaN
# 5     Osoby se žádankou i samoplátce                NaN
# 6     Osoby se žádankou i samoplátce                NaN
# 7     Osoby se žádankou i samoplátce                NaN
# 8                         Samoplátce                NaN
# 9                         Samoplátce                NaN
#
#                                 Způsob rezervace  \
# 0              Přes webové stránky na přesný čas
# 1              Přes webové stránky na přesný čas
# 2                            Přes webové stránky
# 3                            Přes webové stránky
# 4                      www.rezervace.aeskulab.cz
# 5                            Přes webové stránky
# 6                 Elektronický rezervační systém
# 7                 Elektronický rezervační systém
# 8  Online rezervační portál nebo telefonní linka
# 9  Online rezervační portál nebo telefonní linka
#
#      Odkaz na rezervační systém DRIVE-IN
# 0              www.nazadanku.cz       Ne
# 1              www.nazadanku.cz      Ano
# 2                www.vysetri.me       Ne
# 3                www.vysetri.me      Ano
# 4     www.rezervace.aeskulab.cz       Ne
# 5         rezervace.aeskulab.cz       Ne
# 6         rezervace.aeskulab.cz       Ne
# 7         rezervace.aeskulab.cz       Ne
# 8  www.antigenni-testy-covid.cz       Ne
# 9  www.antigenni-testy-covid.cz       Ne

# %% [markdown]
# I have tried to scrap the calendar, saved in csv file.

# %%
def calnedar(url): # Created the second function which grabs all necessary information form each comapny and returns
    r = requests.get(url)
    soup= BeautifulSoup(r.text,'lxml')
    company_calendars={
        'Calendar':soup.select_one('div.slots__list').text.strip().replace('\n',' ')
    }
    
    return company_calendars
Ca=calnedar('https://testovani.uzis.cz/Detail?id=f4d02b50-1561-4c7e-9cf4-8d85b2d985ea&backURL=/')
Ca
# Out:
# {'Calendar': 'Po 21.6.   Maximální kapacita     Út 22.6.   Volná kapacita 45 z 56     St 23.6.   Volná kapacita 30 z 56     Čt 24.6.   Volná kapacita 33 z 56     Pá 25.6.   Volná kapacita 42 z 56     So 26.6.   Volná kapacita 42 z 58     Ne 27.6.   Volná kapacita 36 z 58'}

# %%
def all_clendarInfo():# Here I will source all available calendar info.
   #results=[]
   urls= get_page_links('https://testovani.uzis.cz/')
   calnedars=pd.DataFrame([calnedar(url) for url in urls])
   #results.append(comp_info)
   return calnedars

all_clendarInfo()
# Out:
#                                               Calendar
# 0    St 5.5.   Maximální kapacita     Čt 6.5.   Vol...
# 1    St 5.5.   Maximální kapacita     Čt 6.5.   Vol...
# 2    St 5.5.   Maximální kapacita     Čt 6.5.   Vol...
# 3    St 5.5.   Maximální kapacita     Čt 6.5.   Vol...
# 4    St 5.5.   Žádná data     Čt 6.5.   Žádná data ...
# ..                                                 ...
# 317  St 5.5.   Maximální kapacita     Čt 6.5.   Zav...
# 318  St 5.5.   Žádná data     Čt 6.5.   Žádná data ...
# 319  St 5.5.   Žádná data     Čt 6.5.   Žádná data ...
# 320  St 5.5.   Maximální kapacita     Čt 6.5.   Vol...
# 321  St 5.5.   Volná kapacita 55 z 93     Čt 6.5.  ...
#
# [322 rows x 1 columns]

# %%
#Getting capacities info from each calendar line

# %%
cad_dataframe=all_clendarInfo()
cad_dataframe.to_csv('calendar.csv')
